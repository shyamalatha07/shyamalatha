# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
np.mean(df["SAT"])
# Out:
# 1266.44

# %%
np.median(df["SAT"])
# Out:
# 1285.0

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
np.std(df["GradRate"])
# Out:
# 8.874773236539623

# %%
np.var(df["SFRatio"])
# Out:
# 15.881599999999999

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Acceptance Ratio")
plt.hist(df["Accept"])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["Accept"])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df["Accept"], kde = True)   #kde = kernal Density Estimation
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df["SFRatio"], kde = True)
# Out:
# <Axes: xlabel='SFRatio', ylabel='Count'>

# %%
sns.histplot(df["Expenses"], kde = True)
# Out:
# <Axes: xlabel='Expenses', ylabel='Count'>

# %%
sns.histplot(df["GradRate"], kde = True)
# Out:
# <Axes: xlabel='GradRate', ylabel='Count'>

# %%
sns.histplot(df["Top10"], kde = True)
# Out:
# <Axes: xlabel='Top10', ylabel='Count'>

# %%
sns.histplot(df["SAT"], kde = True)
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %% [markdown]
# ### Observations
# - In Acceptance ratio the data distibution is non symmetrical and right skewed
# - in Top10 the data distribution is non symmetrical and left skewed
# - in SFRatio the data distribution is non symmetrical and right skewed
# - in Expenses the data distribution is non symmetrical and right skewed
# - in GradRate the data distribution is non symmetrical and left skewed

# %% [markdown]
# # Visualization using boxplot

# %%
s1 = [20,30,50,40,37,48,58,60]
scores1 = pd.Series(s1)
scores1
# Out:
# 0    20
# 1    30
# 2    50
# 3    40
# 4    37
# 5    48
# 6    58
# 7    60
# dtype: int64

# %%
plt.boxplot(scores1, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f29e5410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f29757d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f29a6150>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f29c0dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f29c3310>],
#  'means': []}

# %%
s1 = [20,30,50,36,28,40,37,48,120,100]
scores1 = pd.Series(s1)
scores1
# Out:
# 0     20
# 1     30
# 2     50
# 3     36
# 4     28
# 5     40
# 6     37
# 7     48
# 8    120
# 9    100
# dtype: int64

# %%
plt.boxplot(scores1, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f2b0d090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f2b0e310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f2ae1010>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f2b0f310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f2b0fad0>],
#  'means': []}

# %%
plt.boxplot(df["SFRatio"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f69868d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f6985990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f6997110>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6960110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f69aaad0>],
#  'means': []}

# %%
plt.boxplot(df["SAT"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f68bf290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f2ad3610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f68d03d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6923b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f6923090>],
#  'means': []}

# %%
plt.boxplot(df["Accept"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f69d5f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f69d7490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f68cc690>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6941d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f69a6e90>],
#  'means': []}

# %%
plt.boxplot(df["Top10"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f6aa6850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f6aa7b90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f6aa5f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6ab0b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f6ab1310>],
#  'means': []}

# %%
plt.boxplot(df["Expenses"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f6c49810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f6c4a850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f6c48ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6c4b990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f6c2c9d0>],
#  'means': []}

# %%
plt.boxplot(df["GradRate"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212f6cbc550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x212f6cbd890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x212f6cb3b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x212f6cbe7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212f6c8e350>],
#  'means': []}

# %% [markdown]
# ### Outlier for Universities
# - Outlier present in Accept,Top10,SFRatio,SAT
# - Outlier doesnot present in Expenses, GradRate
# - More outliers are present in SAT and Top10
